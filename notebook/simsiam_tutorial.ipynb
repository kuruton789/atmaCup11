# %% [markdown]
# # はじめに
# このノートブックではSelf-Supervised Learning（以下SSL）の一種である**SimSiam**を用いて、与えられた美術作品に関しての表現学習を行います。SSLはラベルを利用せずデータそのものから擬似的に教師データを作ってデータの表現を学習する手法で、今回のように事前学習済み重みが禁止されている場合においても「より良い重み」を得るのに使える可能性があります。
# SSLの一種であるSimSiamは2つのネットワークに対して異なるデータ拡張を施して類似度を近づけるように学習させる手法で、負例を用意せずにシンプルに学習を行えるという特徴があります。
# <img src="https://tech.fusic.co.jp/uploads/exploring_siam_arcs.png" width=60%>
# 今回はSSLを簡単に行うことができるライブラリ**lightly**を用いてSimSiamによる表現学習を行います。公式のチュートリアルに従って、表現学習を行い、得られたembeddingからデータの分布を確認することが目的となります。
# (※Pretrained Modelは使用しないよう注意しましょう)
#
# 【参考資料】
# [Exploring Simple Siamese Representation Learning](https://arxiv.org/abs/2011.10566)
# [自己教師あり学習の新しいアプローチ / SimSiam: Exploring Simple Siamese Representation Learning](https://speakerdeck.com/sansandsoc/simsiam-exploring-simple-siamese-representation-learning)
# [【論文読み】Exploring Simple Siamese Representation Learning](https://tech.fusic.co.jp/posts/2020-12-25-ml-simsiam-representation-learning/)
# [https://github.com/lightly-ai/lightly](https://github.com/lightly-ai/lightly)
# [Train SimSiam on satellite images](https://docs.lightly.ai/tutorials/package/tutorial_simsiam_esa.html)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# For Colab
# !pip install lightly
# Out:
# Requirement already satisfied: lightly in /usr/local/lib/python3.7/dist-packages (1.1.15)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.19.5)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.3.8)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.1.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.61.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2021.5.30)
# Requirement already satisfied: lightly-utils==0.0.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (0.0.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.10.0+cu102)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.2.0)
# Requirement already satisfied: PyYAML<=5.4.1,>=5.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (5.4.1)
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.4.1)
# Requirement already satisfied: torchmetrics>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.4.1)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.18.2)
# Requirement already satisfied: pillow!=8.3.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (7.1.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (21.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2021.7.0)
# Requirement already satisfied: pyDeprecate==0.3.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.3.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.9.0+cu102)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (4.8)
# Requirement already satisfied: omegaconf==2.1.* in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (2.1.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.34.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.12.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.32.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.36.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning>=1.0.4->lightly) (2.4.7)
# Requirement already satisfied: aiohttp; extra == "http" in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (3.7.4.post0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->pytorch-lightning>=1.0.4->lightly) (3.7.4.3)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.7/dist-packages (from importlib-resources; python_version < "3.9"->hydra-core>=1.0.0->lightly) (3.5.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.6.3)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.1.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)

# %%
# For Colab
# !unzip dataset_atmaCup11.zip
# !mkdir imgs
# !unzip photos.zip -d ./imgs/

# %% [markdown]
# # SimSiamによる表現学習

# %% [markdown]
# ### ライブラリの読み込み

# %%
import math
import torch
import torch.nn as nn
import torchvision
import numpy as np
import lightly

# %% [markdown]
# ### Config

# %% [markdown]
# - `batch_size`はより大きい方がよいかもしれません（論文参照）
# - `num_ftrs`は画像認識モデルのembedding数を表しており、今回は`resnet18`を使用しているため512となります

# %%
num_workers = 2
batch_size = 256
seed = 1
epochs = 400
input_size = 224

# dimension of the embeddings
num_ftrs = 512
# dimension of the output of the prediction and projection heads
out_dim = proj_hidden_dim = 512
# the prediction head uses a bottleneck architecture
pred_hidden_dim = 128
# use 2 layers in the projection head
num_mlp_layers = 2

# %% [markdown]
# ### Seed / 画像データのPath

# %%
# seed torch and numpy
torch.manual_seed(0)
np.random.seed(0)

# set the path to the dataset

path_to_data = '/content/drive/MyDrive/atmaCup/#11/dataset_atmaCup11/inputs/photos'

# %% [markdown]
# ### DataLoader

# %% [markdown]
# - `collate_fn`でDataAugmentationと適用される確率を指定しています。
#   - hf_prob: Horizontal flip
#   - vf_prob: Vertical flip
#   - rr_prob: Random (+90 degree) rotation
#   - min_scale: Random Cropの最小スケール
#   - cj_prob: Color jitter
#   - cj_bright: Brightness jitter
#   - cj_contrast: Contrast jitter
#   - cj_hue: Hue jitter
#   - cj_sat: Saturation jitter
# - 参考： https://docs.lightly.ai/lightly.data.html#lightly.data.collate.ImageCollateFunction

# %%
# define the augmentations for self-supervised learning
collate_fn = lightly.data.ImageCollateFunction(
    input_size=input_size,
    # require invariance to flips and rotations
    hf_prob=0.5,
    vf_prob=0.5,
    rr_prob=0.5,
    # satellite images are all taken from the same height
    # so we use only slight random cropping
    min_scale=0.5,
    # use a weak color jitter for invariance w.r.t small color changes
    # cj_prob=0.2,
    # cj_bright=0.1,
    # cj_contrast=0.1,
    # cj_hue=0.1,
    # cj_sat=0.1,
)

# create a lightly dataset for training, since the augmentations are handled
# by the collate function, there is no need to apply additional ones here
dataset_train_simsiam = lightly.data.LightlyDataset(
    input_dir=path_to_data
)

# create a dataloader for training
dataloader_train_simsiam = torch.utils.data.DataLoader(
    dataset_train_simsiam,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn,
    drop_last=True,
    num_workers=num_workers
)

# create a torchvision transformation for embedding the dataset after training
# here, we resize the images to match the input size during training and apply
# a normalization of the color channel based on statistics from imagenet
test_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((input_size, input_size)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(
        mean=lightly.data.collate.imagenet_normalize['mean'],
        std=lightly.data.collate.imagenet_normalize['std'],
    )
])



# create a lightly dataset for embedding
dataset_test = lightly.data.LightlyDataset(
    input_dir=path_to_data,
    transform=test_transforms
)



# create a dataloader for embedding
dataloader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=batch_size,
    shuffle=False,
    drop_last=False,
    num_workers=num_workers
)

# %% [markdown]
# ### Model

# %% [markdown]
# - ResNet18の最終層を取り除くことでBackboneレイヤーとしています
# - ※Pretrained Modelは使用しないよう注意しましょう

# %%
# we use a pretrained resnet for this tutorial to speed
# up training time but you can also train one from scratch
# Do not use pretrained Model
resnet = torchvision.models.resnet18(pretrained=False)
backbone = nn.Sequential(*list(resnet.children())[:-1])

# create the SimSiam model using the backbone from above
model = lightly.models.SimSiam(
    backbone,
    num_ftrs=num_ftrs,
    #proj_hidden_dim=proj_hidden_dim, # defaultを使用
    #pred_hidden_dim=pred_hidden_dim, # defaultを使用
    #out_dim=out_dim, # defaultを使用
    num_mlp_layers=2
)

# %% [markdown]
# ### Loss / Optimizer

# %%
# SimSiam uses a symmetric negative cosine similarity loss
criterion = lightly.loss.SymNegCosineSimilarityLoss()

# scale the learning rate
lr = 0.05 * batch_size / 256
# use SGD with momentum and weight decay
optimizer = torch.optim.SGD(
    model.parameters(),
    lr=lr,
    momentum=0.9,
    weight_decay=5e-4
)

# %%
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, epochs)

# %% [markdown]
# ### SimSiamによるSelf-Supervised Learning

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

avg_loss = 0.
avg_output_std = 0.
for e in range(epochs):

    for (x0, x1), _, _ in dataloader_train_simsiam:
        # move images to the gpu
        x0 = x0.to(device)
        x1 = x1.to(device)

        # run the model on both transforms of the images
        # the output of the simsiam model is a y containing the predictions
        # and projections for each input x
        y0, y1 = model(x0, x1)

        # backpropagation
        loss = criterion(y0, y1)
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()

        # calculate the per-dimension standard deviation of the outputs
        # we can use this later to check whether the embeddings are collapsing
        output, _ = y0
        output = output.detach()
        output = torch.nn.functional.normalize(output, dim=1)

        output_std = torch.std(output, 0)
        output_std = output_std.mean()

        # use moving averages to track the loss and standard deviation
        w = 0.9
        avg_loss = w * avg_loss + (1 - w) * loss.item()
        avg_output_std = w * avg_output_std + (1 - w) * output_std.item()
    
    scheduler.step()

    # the level of collapse is large if the standard deviation of the l2
    # normalized output is much smaller than 1 / sqrt(dim)
    collapse_level = max(0., 1 - math.sqrt(out_dim) * avg_output_std)
    # print intermediate results
    print(f'[Epoch {e:3d}] '
        f'Loss = {avg_loss:.2f} | '
        f'Collapse Level: {collapse_level:.2f} / 1.00')
# Out:
# [Epoch   0] Loss = -0.30 | Collapse Level: 0.58 / 1.00
# [Epoch   1] Loss = -0.74 | Collapse Level: 0.70 / 1.00
# [Epoch   2] Loss = -0.80 | Collapse Level: 0.73 / 1.00
# [Epoch   3] Loss = -0.84 | Collapse Level: 0.74 / 1.00
# [Epoch   4] Loss = -0.85 | Collapse Level: 0.75 / 1.00
# [Epoch   5] Loss = -0.85 | Collapse Level: 0.76 / 1.00
# [Epoch   6] Loss = -0.86 | Collapse Level: 0.76 / 1.00
# [Epoch   7] Loss = -0.84 | Collapse Level: 0.74 / 1.00
# [Epoch   8] Loss = -0.86 | Collapse Level: 0.76 / 1.00
# [Epoch   9] Loss = -0.85 | Collapse Level: 0.75 / 1.00
# [Epoch  10] Loss = -0.82 | Collapse Level: 0.74 / 1.00
# [Epoch  11] Loss = -0.83 | Collapse Level: 0.74 / 1.00
# [Epoch  12] Loss = -0.84 | Collapse Level: 0.74 / 1.00
# [Epoch  13] Loss = -0.80 | Collapse Level: 0.72 / 1.00
# [Epoch  14] Loss = -0.77 | Collapse Level: 0.70 / 1.00
# [Epoch  15] Loss = -0.46 | Collapse Level: 0.58 / 1.00
# [Epoch  16] Loss = -0.42 | Collapse Level: 0.56 / 1.00
# [Epoch  17] Loss = -0.49 | Collapse Level: 0.57 / 1.00
# [Epoch  18] Loss = -0.52 | Collapse Level: 0.58 / 1.00
# [Epoch  19] Loss = -0.53 | Collapse Level: 0.56 / 1.00
# [Epoch  20] Loss = -0.52 | Collapse Level: 0.56 / 1.00
# [Epoch  21] Loss = -0.55 | Collapse Level: 0.57 / 1.00
# [Epoch  22] Loss = -0.54 | Collapse Level: 0.56 / 1.00
# [Epoch  23] Loss = -0.54 | Collapse Level: 0.55 / 1.00
# [Epoch  24] Loss = -0.58 | Collapse Level: 0.56 / 1.00
# [Epoch  25] Loss = -0.59 | Collapse Level: 0.56 / 1.00
# [Epoch  26] Loss = -0.58 | Collapse Level: 0.56 / 1.00
# [Epoch  27] Loss = -0.58 | Collapse Level: 0.55 / 1.00
# [Epoch  28] Loss = -0.60 | Collapse Level: 0.55 / 1.00
# [Epoch  29] Loss = -0.59 | Collapse Level: 0.55 / 1.00
# [Epoch  30] Loss = -0.61 | Collapse Level: 0.54 / 1.00
# [Epoch  31] Loss = -0.60 | Collapse Level: 0.54 / 1.00
# [Epoch  32] Loss = -0.62 | Collapse Level: 0.54 / 1.00
# [Epoch  33] Loss = -0.61 | Collapse Level: 0.54 / 1.00
# [Epoch  34] Loss = -0.61 | Collapse Level: 0.54 / 1.00
# [Epoch  35] Loss = -0.60 | Collapse Level: 0.54 / 1.00
# [Epoch  36] Loss = -0.59 | Collapse Level: 0.54 / 1.00
# [Epoch  37] Loss = -0.60 | Collapse Level: 0.54 / 1.00
# [Epoch  38] Loss = -0.62 | Collapse Level: 0.54 / 1.00
# [Epoch  39] Loss = -0.61 | Collapse Level: 0.54 / 1.00
# [Epoch  40] Loss = -0.61 | Collapse Level: 0.54 / 1.00
# [Epoch  41] Loss = -0.61 | Collapse Level: 0.54 / 1.00
# [Epoch  42] Loss = -0.63 | Collapse Level: 0.54 / 1.00
# [Epoch  43] Loss = -0.63 | Collapse Level: 0.53 / 1.00
# [Epoch  44] Loss = -0.62 | Collapse Level: 0.54 / 1.00
# [Epoch  45] Loss = -0.61 | Collapse Level: 0.54 / 1.00
# [Epoch  46] Loss = -0.63 | Collapse Level: 0.53 / 1.00
# [Epoch  47] Loss = -0.62 | Collapse Level: 0.53 / 1.00
# [Epoch  48] Loss = -0.64 | Collapse Level: 0.53 / 1.00
# [Epoch  49] Loss = -0.66 | Collapse Level: 0.52 / 1.00
# [Epoch  50] Loss = -0.67 | Collapse Level: 0.53 / 1.00
# [Epoch  51] Loss = -0.67 | Collapse Level: 0.52 / 1.00
# [Epoch  52] Loss = -0.67 | Collapse Level: 0.52 / 1.00
# [Epoch  53] Loss = -0.67 | Collapse Level: 0.52 / 1.00
# [Epoch  54] Loss = -0.68 | Collapse Level: 0.52 / 1.00
# [Epoch  55] Loss = -0.68 | Collapse Level: 0.52 / 1.00
# [Epoch  56] Loss = -0.69 | Collapse Level: 0.52 / 1.00
# [Epoch  57] Loss = -0.70 | Collapse Level: 0.52 / 1.00
# [Epoch  58] Loss = -0.68 | Collapse Level: 0.52 / 1.00
# [Epoch  59] Loss = -0.70 | Collapse Level: 0.52 / 1.00
# [Epoch  60] Loss = -0.69 | Collapse Level: 0.52 / 1.00
# [Epoch  61] Loss = -0.71 | Collapse Level: 0.52 / 1.00
# [Epoch  62] Loss = -0.71 | Collapse Level: 0.52 / 1.00
# [Epoch  63] Loss = -0.71 | Collapse Level: 0.52 / 1.00
# [Epoch  64] Loss = -0.72 | Collapse Level: 0.52 / 1.00
# [Epoch  65] Loss = -0.72 | Collapse Level: 0.52 / 1.00
# [Epoch  66] Loss = -0.72 | Collapse Level: 0.52 / 1.00
# [Epoch  67] Loss = -0.71 | Collapse Level: 0.52 / 1.00
# [Epoch  68] Loss = -0.71 | Collapse Level: 0.52 / 1.00
# [Epoch  69] Loss = -0.71 | Collapse Level: 0.52 / 1.00
# [Epoch  70] Loss = -0.71 | Collapse Level: 0.52 / 1.00
# [Epoch  71] Loss = -0.71 | Collapse Level: 0.51 / 1.00
# [Epoch  72] Loss = -0.72 | Collapse Level: 0.51 / 1.00
# [Epoch  73] Loss = -0.72 | Collapse Level: 0.51 / 1.00
# [Epoch  74] Loss = -0.72 | Collapse Level: 0.51 / 1.00
# [Epoch  75] Loss = -0.73 | Collapse Level: 0.51 / 1.00
# [Epoch  76] Loss = -0.72 | Collapse Level: 0.51 / 1.00
# [Epoch  77] Loss = -0.73 | Collapse Level: 0.51 / 1.00
# [Epoch  78] Loss = -0.73 | Collapse Level: 0.51 / 1.00
# [Epoch  79] Loss = -0.73 | Collapse Level: 0.51 / 1.00
# [Epoch  80] Loss = -0.74 | Collapse Level: 0.51 / 1.00
# [Epoch  81] Loss = -0.73 | Collapse Level: 0.51 / 1.00
# [Epoch  82] Loss = -0.74 | Collapse Level: 0.51 / 1.00
# [Epoch  83] Loss = -0.74 | Collapse Level: 0.51 / 1.00
# [Epoch  84] Loss = -0.74 | Collapse Level: 0.51 / 1.00
# [Epoch  85] Loss = -0.74 | Collapse Level: 0.51 / 1.00
# [Epoch  86] Loss = -0.74 | Collapse Level: 0.51 / 1.00
# [Epoch  87] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch  88] Loss = -0.74 | Collapse Level: 0.51 / 1.00
# [Epoch  89] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch  90] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch  91] Loss = -0.74 | Collapse Level: 0.51 / 1.00
# [Epoch  92] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch  93] Loss = -0.77 | Collapse Level: 0.51 / 1.00
# [Epoch  94] Loss = -0.77 | Collapse Level: 0.51 / 1.00
# [Epoch  95] Loss = -0.77 | Collapse Level: 0.51 / 1.00
# [Epoch  96] Loss = -0.76 | Collapse Level: 0.51 / 1.00
# [Epoch  97] Loss = -0.76 | Collapse Level: 0.51 / 1.00
# [Epoch  98] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch  99] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch 100] Loss = -0.76 | Collapse Level: 0.51 / 1.00
# [Epoch 101] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch 102] Loss = -0.76 | Collapse Level: 0.51 / 1.00
# [Epoch 103] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch 104] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch 105] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch 106] Loss = -0.76 | Collapse Level: 0.51 / 1.00
# [Epoch 107] Loss = -0.76 | Collapse Level: 0.51 / 1.00
# [Epoch 108] Loss = -0.75 | Collapse Level: 0.51 / 1.00
# [Epoch 109] Loss = -0.77 | Collapse Level: 0.51 / 1.00
# [Epoch 110] Loss = -0.77 | Collapse Level: 0.51 / 1.00
# [Epoch 111] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 112] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 113] Loss = -0.76 | Collapse Level: 0.51 / 1.00
# [Epoch 114] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 115] Loss = -0.77 | Collapse Level: 0.51 / 1.00
# [Epoch 116] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 117] Loss = -0.75 | Collapse Level: 0.50 / 1.00
# [Epoch 118] Loss = -0.75 | Collapse Level: 0.50 / 1.00
# [Epoch 119] Loss = -0.75 | Collapse Level: 0.50 / 1.00
# [Epoch 120] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 121] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 122] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 123] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 124] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 125] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 126] Loss = -0.75 | Collapse Level: 0.50 / 1.00
# [Epoch 127] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 128] Loss = -0.75 | Collapse Level: 0.50 / 1.00
# [Epoch 129] Loss = -0.75 | Collapse Level: 0.50 / 1.00
# [Epoch 130] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 131] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 132] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 133] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 134] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 135] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 136] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 137] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 138] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 139] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 140] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 141] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 142] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 143] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 144] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 145] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 146] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 147] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 148] Loss = -0.76 | Collapse Level: 0.50 / 1.00
# [Epoch 149] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 150] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 151] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 152] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 153] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 154] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 155] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 156] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 157] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 158] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 159] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 160] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 161] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 162] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 163] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 164] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 165] Loss = -0.77 | Collapse Level: 0.50 / 1.00
# [Epoch 166] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 167] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 168] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 169] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 170] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 171] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 172] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 173] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 174] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 175] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 176] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 177] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 178] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 179] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 180] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 181] Loss = -0.78 | Collapse Level: 0.50 / 1.00
# [Epoch 182] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 183] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 184] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 185] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 186] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 187] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 188] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 189] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 190] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 191] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 192] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 193] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 194] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 195] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 196] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 197] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 198] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 199] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 200] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 201] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 202] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 203] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 204] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 205] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 206] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 207] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 208] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 209] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 210] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 211] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 212] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 213] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 214] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 215] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 216] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 217] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 218] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 219] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 220] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 221] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 222] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 223] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 224] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 225] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 226] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 227] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 228] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 229] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 230] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 231] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 232] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 233] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 234] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 235] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 236] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 237] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 238] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 239] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 240] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 241] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 242] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 243] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 244] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 245] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 246] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 247] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 248] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 249] Loss = -0.79 | Collapse Level: 0.50 / 1.00
# [Epoch 250] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 251] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 252] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 253] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 254] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 255] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 256] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 257] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 258] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 259] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 260] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 261] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 262] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 263] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 264] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 265] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 266] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 267] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 268] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 269] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 270] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 271] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 272] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 273] Loss = -0.80 | Collapse Level: 0.50 / 1.00
# [Epoch 274] Loss = -0.82 | Collapse Level: 0.50 / 1.00
# [Epoch 275] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 276] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# [Epoch 277] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 278] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 279] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 280] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 281] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 282] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 283] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 284] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 285] Loss = -0.81 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
# ...
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 395] Loss = -0.82 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
# AssertionError: can only test a child process
# [Epoch 396] Loss = -0.82 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 397] Loss = -0.82 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 398] Loss = -0.82 | Collapse Level: 0.50 / 1.00
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fde180cee60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# [Epoch 399] Loss = -0.82 | Collapse Level: 0.50 / 1.00

# %%
x0.shape

# %% [markdown]
# # 埋め込み表現の可視化

# %% [markdown]
# ### embeddingの取得

# %%
embeddings = []
filenames = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for i, (x, _, fnames) in enumerate(dataloader_test):
        # move the images to the gpu
        x = x.to(device)
        # embed the images with the pre-trained backbone
        y = model.backbone(x)
        y = y.squeeze()
        # store the embeddings and filenames in lists
        embeddings.append(y)
        filenames = filenames + list(fnames)

# concatenate the embeddings and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %% [markdown]
# ### plot用のライブラリ読み込み

# %%
# for plotting
import os
from PIL import Image

import matplotlib.pyplot as plt
import matplotlib.offsetbox as osb
from matplotlib import rcParams as rcp

# for resizing images to thumbnails
import torchvision.transforms.functional as functional

# for clustering and 2d representations
from sklearn import random_projection

# %% [markdown]
# ### embeddingの次元削減とNormalizing

# %%
# for the scatter plot we want to transform the images to a two-dimensional
# vector space using a random Gaussian projection
projection = random_projection.GaussianRandomProjection(n_components=2)
embeddings_2d = projection.fit_transform(embeddings)

# normalize the embeddings to fit in the [0, 1] square
M = np.max(embeddings_2d, axis=0)
m = np.min(embeddings_2d, axis=0)
embeddings_2d = (embeddings_2d - m) / (M - m)

# %% [markdown]
# ### 散布図形式のサムネイル可視化

# %%
def get_scatter_plot_with_thumbnails():
    """Creates a scatter plot with image overlays.
    """
    # initialize empty figure and add subplot
    fig = plt.figure(figsize=(12,12))
    fig.suptitle('SimSiam Scatter Plot')
    ax = fig.add_subplot(1, 1, 1)
    # shuffle images and find out which images to show
    shown_images_idx = []
    shown_images = np.array([[1., 1.]])
    iterator = [i for i in range(embeddings_2d.shape[0])]
    np.random.shuffle(iterator)
    for i in iterator:
        # only show image if it is sufficiently far away from the others
        dist = np.sum((embeddings_2d[i] - shown_images) ** 2, 1)
        if np.min(dist) < 1.5e-3:
            continue
        shown_images = np.r_[shown_images, [embeddings_2d[i]]]
        shown_images_idx.append(i)

    # plot image overlays
    for idx in shown_images_idx:
        thumbnail_size = int(rcp['figure.figsize'][0] * 5.)
        path = os.path.join(path_to_data, filenames[idx])
        img = Image.open(path)
        img = functional.resize(img, thumbnail_size)
        img = np.array(img)
        img_box = osb.AnnotationBbox(
            osb.OffsetImage(img, cmap=plt.cm.gray_r),
            embeddings_2d[idx],
            pad=0.2,
        )
        ax.add_artist(img_box)

    # set aspect ratio
    ratio = 1. / ax.get_data_ratio()
    ax.set_aspect(ratio, adjustable='box')


# get a scatter plot with thumbnail overlays
get_scatter_plot_with_thumbnails()

# %% [markdown]
# 比較的近い色調・表現の絵同士が集まっており、表現学習が行えていることが分かります

# %% [markdown]
# ### 類似画像の可視化

# %%
def get_image_as_np_array(filename: str):
    """Loads the image with filename and returns it as a numpy array.

    """
    img = Image.open(filename)
    return np.asarray(img)[...,:3]


def get_image_as_np_array_with_frame(filename: str, w: int = 5):
    """Returns an image as a numpy array with a black frame of width w.

    """
    img = get_image_as_np_array(filename)
    ny, nx, _ = img.shape
    # create an empty image with padding for the frame
    framed_img = np.zeros((w + ny + w, w + nx + w, 3))
    framed_img = framed_img.astype(np.uint8)
    # put the original image in the middle of the new one
    framed_img[w:-w, w:-w] = img
    return framed_img


def plot_nearest_neighbors_3x3(example_image: str, i: int):
    """Plots the example image and its eight nearest neighbors.

    """
    n_subplots = 9
    # initialize empty figure
    fig = plt.figure()
    fig.suptitle(f"Nearest Neighbor Plot {i + 1}")
    #
    example_idx = filenames.index(example_image)
    # get distances to the cluster center
    distances = embeddings - embeddings[example_idx]
    distances = np.power(distances, 2).sum(-1).squeeze()
    # sort indices by distance to the center
    nearest_neighbors = np.argsort(distances)[:n_subplots]
    # show images
    for plot_offset, plot_idx in enumerate(nearest_neighbors):
        ax = fig.add_subplot(3, 3, plot_offset + 1)
        # get the corresponding filename
        fname = os.path.join(path_to_data, filenames[plot_idx])
        if plot_offset == 0:
            ax.set_title(f"Example Image")
            plt.imshow(get_image_as_np_array_with_frame(fname))
        else:
            plt.imshow(get_image_as_np_array(fname))
        # let's disable the axis
        plt.axis("off")

# %%
# show example images for each cluster
example_images = [
    '0a207830d8cca27de4be.jpg',
    '000bd5e82eb22f199f44.jpg',
    '4193ebdc9a860f646a40.jpg',
    '0cd8af895677b51c5897.jpg',
    '0a44488ae1db7d79d033.jpg',
]

for i, example_image in enumerate(example_images):
    plot_nearest_neighbors_3x3(example_image, i)

# %% [markdown]
# 人物画・花・生き物などがそれぞれ類似画像として提案されているようです

# %% [markdown]
# ## 学習済みモデルの活用

# %% [markdown]
# SimSiamによる学習済みのResNet18は`model.backbone`として呼び出すことができます  。
# これを用いて更に教師あり学習を行ったり、学習済みembeddingを推論に活用することが可能です。
# （教師あり学習を行う場合は最終層にLinear層を追加する必要があることに注意してください）

# %%
model.backbone

# %%
dataset_root = '/content/drive/MyDrive/atmaCup/#11/dataset_atmaCup11'
assert dataset_root is not None
output_dir = os.path.join(dataset_root, "simsam_tutorial")
os.makedirs(output_dir, exist_ok=True)

# %%
model_path = os.path.join(output_dir, str(batch_size) + '_' + str(epochs) + '_' + str(input_size) + '_' + str(avg_loss) + '.pth')

torch.save(model.state_dict(), model_path)
