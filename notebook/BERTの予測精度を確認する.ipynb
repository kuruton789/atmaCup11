# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

import pandas as pd
import numpy as np
from glob import  glob

import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_root = '/content/drive/MyDrive/atmaCup/#11/dataset_atmaCup11'
assert dataset_root is not None

BERT_materials = pd.read_csv(os.path.join(dataset_root, 'inputs/BERT_materials_1d.csv'))
BERT_materials_pred = pd.read_csv(os.path.join(dataset_root, 'output_materials_ver1/train_materials.csv'))

BERT_techniques = pd.read_csv(os.path.join(dataset_root, 'inputs/BERT_techniques_1d.csv'))
BERT_techniques_pred = pd.read_csv(os.path.join(dataset_root, 'output_techniques_ver1/train_techniques.csv'))

# %%
BERT_materials_pred.head()
# Out:
#               object_id  pred_BERT_materials
# 0  002bff09b09998d0be65             0.609680
# 1  00309fb1ef05416f9c1f             1.658821
# 2  003a1562e97f79ba96dc            -1.667907
# 3  004890880e8e7431147b             0.054919
# 4  00718c32602425f504c1            -0.672557

# %%
plt.scatter(BERT_materials['BERT_materials_0'], BERT_materials_pred['pred_BERT_materials'][:3936])

# %%
len(BERT_techniques)
# Out:
# 3936

# %%
plt.scatter(BERT_techniques['BERT_techniques_0'], BERT_techniques_pred['pred_BERT_techniques'][:3936])
